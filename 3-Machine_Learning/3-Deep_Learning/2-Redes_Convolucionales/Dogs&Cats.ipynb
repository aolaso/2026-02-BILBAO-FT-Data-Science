# %% [markdown]
# ## Redes Convolucionales
# #### Ejemplo clasificación de perros y gatos para CAPTCHA
#
# Este notebook utiliza datos de la [competición de Kaggle Dogs vs. Cats](https://www.kaggle.com/c/dogs-vs-cats/overview). En esta competicion se utiliza Asirra (Animal Species Image Recognition for Restricting Access), CAPTCHA que sirve para diferenciar entre una persona o una máquina accediendo a una página web. Este tipo de "pruebas" se utilizan para evitar emails de spam, y ataques por fuerza bruta contra servidores.
#
# En este notebook vamos a probar que hay técnicas de clasificado automáticas de imágenes mediante redes neuronales, que con las que se intenta saltar CAPTCHA

# %%
# %pip install scikit-image opencv-python # numpy pandas scikit-learn matplotlib keras seaborn tensorflow
# Out:
# Requirement already satisfied: scikit-image in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (0.26.0)
# Requirement already satisfied: opencv-python in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.24 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (12.2.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages (from scikit-image) (0.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Library

# %%
import subprocess
result = subprocess.run(['pip', 'show', 'tensorflow', 'tensorflow-macos'], capture_output=True, text=True)
print(result.stdout)
# Out:
# Name: tensorflow-macos
# Version: 2.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by:

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.__file__)
# Out:
# 2.15.0
# /opt/homebrew/Caskroom/miniforge/base/envs/dl/lib/python3.11/site-packages/tensorflow/__init__.py

# %%
import sys
print(sys.executable)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/dl/bin/python

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %% [markdown]
# # Define Constants
# Tendremos una serie de constantes como las dimensiones de las imágenes, que serán fijas a lo largo de todo el notebook

# %%
IMAGE_WIDTH=32
IMAGE_HEIGHT=32
IMAGE_CHANNELS=3
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)
BATCH_SIZE = 32
EPOCHS = 30

# %% [markdown]
# # Prepare Training Data
# 1. Descárgate el dataset desde [aquí](https://drive.google.com/drive/folders/1WUIVV96pTy1SpL-qMenh3UtgDAEY9hNh?usp=sharing)
# 2. Descomprime el dataset y guardalo en la ruta que quieras del ordenador.
# 3. En este punto vamos guardar en una lista las etiquetas de cada foto.

# %%
ROOT_PATH = "/Users/andoni/2026-02-BILBAO-FT-Data-Science/3-Machine_Learning/3-Deep_Learning/2-Redes_Convolucionales/dogs_cats/"

TRAIN_PATH = ROOT_PATH + "train/"
TEST_PATH  = ROOT_PATH + "test/"

# %%
##### CODE #####

# Listar todos los archivos de la carpeta de train (TRAIN_PATH)
filenames = os.listdir(TRAIN_PATH)

# Lista vacia
categories = []

# Iterar
for filename in filenames:
    # Saco el nombre
    category = filename.split('.')[0]
    
    # If else
    # Guardo en lista
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)
    
    
df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df
# Out:
#            filename  category
# 0      cat.2718.jpg         0
# 1      cat.3406.jpg         0
# 2      cat.1211.jpg         0
# 3     dog.11102.jpg         1
# 4     dog.11664.jpg         1
# ...             ...       ...
# 6571  dog.10563.jpg         1
# 6572   cat.1208.jpg         0
# 6573  dog.10205.jpg         1
# 6574  dog.12412.jpg         1
# 6575   cat.2701.jpg         0
#
# [6576 rows x 2 columns]

# %% [markdown]
# ### See Total In count

# %%
df['category'].value_counts().plot.bar();

# %% [markdown]
# # See sample image

# %%
from skimage.io import imread
import cv2

sample = random.choice(filenames)
image = imread(TRAIN_PATH + sample)

print(image.shape)
print(np.max(image))
plt.imshow(image);
# Out:
# (414, 310, 3)
# 255

# %% [markdown]
# Una imagen no es mas que un array de HxWxC píxeles, siendo H(Height) y W(Width) las dimensiones de resolución de la imagen, y C el número de canales. Habrá tres valores por píxel.

# %%
image
# Out:
# array([[[180, 167, 150],
#         [172, 159, 142],
#         [161, 148, 131],
#         ...,
#         [ 87,  55,  34],
#         [ 84,  52,  31],
#         [ 82,  50,  29]],
#
#        [[174, 161, 144],
#         [173, 160, 143],
#         [172, 159, 142],
#         ...,
#         [ 87,  55,  34],
#         [ 85,  53,  32],
#         [ 83,  51,  30]],
#
#        [[164, 151, 134],
#         [168, 155, 138],
#         [173, 160, 143],
#         ...,
#         [ 87,  55,  34],
#         [ 86,  54,  33],
#         [ 84,  52,  31]],
#
#        ...,
#
#        [[167, 154, 137],
#         [167, 154, 137],
#         [168, 155, 138],
#         ...,
#         [116, 102,  93],
#         [120, 106,  97],
#         [153, 139, 130]],
#
#        [[167, 154, 137],
#         [167, 154, 137],
#         [168, 155, 138],
#         ...,
#         [130, 116, 107],
#         [112,  98,  89],
#         [131, 117, 108]],
#
#        [[167, 154, 137],
#         [167, 154, 137],
#         [168, 155, 138],
#         ...,
#         [148, 134, 125],
#         [116, 102,  93],
#         [124, 110, 101]]], dtype=uint8)

# %% [markdown]
# # Resize image
# Cargar todas las imágenes a la vez es un problema ya que son un total de 25000 (unos 500MB la carpeta de train). Este proceso require mucha memoria, por lo que tendremos que aplicarle un resize a cada imagen para bajarlas de resolución. Esto también nos sirve para solventar el problema de tener imágenes con distintas resoluciones.

# %%
plt.figure(figsize=(12, 12))

sample = random.choice(filenames)
image = imread(TRAIN_PATH + sample)
imagesmall = cv2.resize(image, (IMAGE_WIDTH, IMAGE_HEIGHT))

print("Tamaño imagen original:", image.shape)
print("Tamaño imagen reshape:", imagesmall.shape)

# Original image
plt.subplot(1, 2, 1)
plt.imshow(image)

# Resized image
plt.subplot(1, 2, 2)
plt.imshow(imagesmall);
# Out:
# Tamaño imagen original: (469, 500, 3)
# Tamaño imagen reshape: (32, 32, 3)

# %% [markdown]
# # Color
# Podríamos cargar las imágenes como blanco y negro, de esta forma se reduciría el espacio de features considerablemente al contar con un único canal

# %%
sample = random.choice(filenames)

image = cv2.imread(filename = TRAIN_PATH + sample, flags = cv2.IMREAD_GRAYSCALE)

print("Tamaño imagen original:", image.shape)
plt.imshow(image, cmap='gray');
# Out:
# Tamaño imagen original: (375, 499)

# %% [markdown]
# # Load data
# Llega el momento de cargar los datos. Ya no estan sencillo como cuando teníamos datasets en CSVs puesto que ahora hay que cargar miles de archivos en memoria en este notebook. Para ello necesitaremos un programa iterativo que vaya recorriendo los archivos de la carpeta, cargarlos como array de numpy y almacenarlos en un objeto.

# %%
def read_data(path, im_size):
    X = []
    Y = []

    ##### CODE #####
    # Iterar sobre todo lo que haya en path
    for file in os.listdir(path):
        
        # Leer la imagen a color y aplicarle el resize
        image = imread(path + file)
        smallimage = cv2.resize(image, (im_size, im_size))
        
        # Guardo en X
        X.append(smallimage)
        
        category = file.split('.')[0]
        # Miro si es perro y gato para guardar en Y
        if category == 'dog':
            Y.append(1)
        else:
            Y.append(0)
        

    return np.array(X), np.array(Y)

# %%
X_train, y_train = read_data(TRAIN_PATH, IMAGE_WIDTH)
X_test, y_test = read_data(TEST_PATH, IMAGE_WIDTH)

print(X_train.shape)
print(X_test.shape)
# Out:
# (6576, 32, 32, 3)
# (3456, 32, 32, 3)

# %%
os.listdir(TRAIN_PATH)[1]
# Out:
# 'cat.3406.jpg'

# %%
print(X_train[1].shape)
plt.imshow(X_train[1]);
# Out:
# (32, 32, 3)

# %%
X_train[0]
# Out:
# array([[[ 37,  27,  18],
#         [ 35,  28,  18],
#         [ 36,  26,  17],
#         ...,
#         [103,  59,  32],
#         [108,  68,  43],
#         [105,  71,  44]],
#
#        [[ 35,  25,  16],
#         [ 41,  31,  22],
#         [ 41,  29,  31],
#         ...,
#         [113,  70,  51],
#         [107,  73,  46],
#         [107,  79,  55]],
#
#        [[ 37,  27,  18],
#         [ 43,  33,  24],
#         [194, 183, 191],
#         ...,
#         [111,  74,  45],
#         [111,  76,  54],
#         [109,  79,  55]],
#
#        ...,
#
#        [[ 87,  70,  54],
#         [ 93,  78,  59],
#         [ 92,  77,  58],
#         ...,
#         [ 28,  19,  14],
#         [  9,   5,   0],
#         [ 47,  35,  19]],
#
#        [[ 81,  65,  50],
#         [ 72,  56,  41],
#         [ 74,  58,  42],
#         ...,
#         [  1,   6,   9],
#         [ 17,  18,  14],
#         [ 58,  39,  22]],
#
#        [[ 60,  46,  37],
#         [ 79,  63,  48],
#         [ 85,  73,  51],
#         ...,
#         [ 39,  31,  20],
#         [ 48,  34,  21],
#         [ 50,  38,  24]]], dtype=uint8)

# %% [markdown]
# # Normalized data
# Normalizar los datos hará que entrene mucho mejor la red, al estar todos los pixeles en la misma escala.

# %%
print("Min:", np.min(X_train))
print("Max:", np.max(X_train))
# Out:
# Min: 0
# Max: 255

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

print("Min:", np.min(X_train))
print("Max:", np.max(X_train))
# Out:
# Min: 0.0
# Max: 1.0

# %% [markdown]
# # Shuffle data
# Como hemos cargado los datos de manera ordenada (primero gatos y luego perros), tendremos que desordenarlos para asegurarnos de que no haya ningún sesgo en el entrenamiento ni en la selección de datos de validación.

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train, random_state=42)

# %%
X_train
# Out:
# array([[[[0.22745098, 0.3254902 , 0.41568627],
#          [0.26666667, 0.36470588, 0.45098039],
#          [0.25490196, 0.35686275, 0.42745098],
#          ...,
#          [0.5254902 , 0.32941176, 0.18431373],
#          [0.48627451, 0.30588235, 0.17254902],
#          [0.43921569, 0.2627451 , 0.17254902]],
#
#         [[0.22745098, 0.34117647, 0.40392157],
#          [0.24705882, 0.35294118, 0.41960784],
#          [0.26666667, 0.35294118, 0.43529412],
#          ...,
#          [0.53333333, 0.3372549 , 0.19215686],
#          [0.50588235, 0.30980392, 0.18039216],
#          [0.43921569, 0.26666667, 0.16078431]],
#
#         [[0.26666667, 0.34901961, 0.42352941],
#          [0.2745098 , 0.38039216, 0.44705882],
#          [0.27058824, 0.35686275, 0.43921569],
#          ...,
#          [0.5254902 , 0.32941176, 0.18431373],
#          [0.50588235, 0.30980392, 0.18039216],
#          [0.45098039, 0.27843137, 0.17254902]],
#
#         ...,
#
#         [[0.4745098 , 0.39607843, 0.3372549 ],
#          [0.49411765, 0.40784314, 0.35294118],
#          [0.48627451, 0.40784314, 0.36470588],
#          ...,
#          [0.68627451, 0.38823529, 0.13333333],
#          [0.63921569, 0.3372549 , 0.11764706],
#          [0.58039216, 0.30980392, 0.1372549 ]],
#
#         [[0.45490196, 0.36078431, 0.31372549],
#          [0.45098039, 0.36078431, 0.29803922],
#          [0.45882353, 0.38431373, 0.31372549],
#          ...,
#          [0.69411765, 0.38823529, 0.15294118],
#          [0.61176471, 0.33333333, 0.11372549],
#          [0.55686275, 0.30980392, 0.10980392]],
#
#         [[0.43921569, 0.34509804, 0.2745098 ],
#          [0.4627451 , 0.35686275, 0.28235294],
#          [0.47058824, 0.36078431, 0.27843137],
#          ...,
#          [0.67843137, 0.38431373, 0.12941176],
#          [0.61960784, 0.34509804, 0.14117647],
#          [0.54509804, 0.29411765, 0.12941176]]],
#
#
#        [[[0.09411765, 0.20784314, 0.23921569],
#          [0.12156863, 0.2       , 0.21176471],
#          [0.30980392, 0.36470588, 0.38823529],
#          ...,
#          [0.69803922, 0.44705882, 0.34901961],
#          [0.1372549 , 0.14509804, 0.14117647],
#          [0.20392157, 0.18039216, 0.12941176]],
#
#         [[0.09803922, 0.20784314, 0.26666667],
#          [0.11764706, 0.18431373, 0.25490196],
#          [0.43529412, 0.39215686, 0.39215686],
#          ...,
#          [0.74509804, 0.49411765, 0.39607843],
#          [0.14509804, 0.14509804, 0.14901961],
#          [0.20392157, 0.17647059, 0.15294118]],
#
#         [[0.09019608, 0.2       , 0.2627451 ],
#          [0.09411765, 0.2       , 0.23921569],
#          [0.42352941, 0.44313725, 0.44313725],
#          ...,
#          [0.74509804, 0.48627451, 0.39215686],
#          [0.11372549, 0.14901961, 0.18823529],
#          [0.11372549, 0.1372549 , 0.16470588]],
#
#         ...,
#
#         [[0.30196078, 0.30980392, 0.37647059],
#          [0.33333333, 0.33333333, 0.37647059],
#          [0.2627451 , 0.2627451 , 0.30980392],
#          ...,
#          [0.82352941, 0.70196078, 0.65098039],
#          [0.15294118, 0.1254902 , 0.18039216],
#          [0.37647059, 0.36862745, 0.37647059]],
#
#         [[0.16470588, 0.16078431, 0.19215686],
#          [0.17647059, 0.15686275, 0.17254902],
#          [0.18823529, 0.16862745, 0.18039216],
#          ...,
#          [0.89019608, 0.69803922, 0.62352941],
#          [0.21568627, 0.15686275, 0.21960784],
#          [0.14509804, 0.15686275, 0.14509804]],
#
#         [[0.17647059, 0.17254902, 0.18039216],
#          [0.17647059, 0.16862745, 0.17254902],
#          [0.18039216, 0.17254902, 0.17647059],
#          ...,
#          [0.58823529, 0.40784314, 0.38039216],
#          [0.60392157, 0.50196078, 0.48627451],
#          [0.13333333, 0.14509804, 0.18039216]]],
#
#
#        [[[0.61960784, 0.56470588, 0.38823529],
#          [0.60784314, 0.55294118, 0.36078431],
#          [0.60784314, 0.5372549 , 0.35686275],
#          ...,
#          [0.39215686, 0.29411765, 0.09411765],
#          [0.38431373, 0.28235294, 0.09411765],
#          [0.57647059, 0.40784314, 0.19215686]],
#
#         [[0.62745098, 0.57254902, 0.39607843],
#          [0.6       , 0.54509804, 0.35294118],
#          [0.60392157, 0.53333333, 0.35294118],
#          ...,
#          [0.4       , 0.28235294, 0.14901961],
#          [0.42745098, 0.32941176, 0.17647059],
#          [0.43137255, 0.29019608, 0.07843137]],
#
#         [[0.62745098, 0.57254902, 0.39607843],
#          [0.60392157, 0.54509804, 0.35294118],
#          [0.6       , 0.52941176, 0.34901961],
#          ...,
#          [0.4       , 0.29019608, 0.09803922],
#          [0.4       , 0.32156863, 0.15686275],
#          [0.23137255, 0.12156863, 0.        ]],
#
#         ...,
#
#         [[0.61176471, 0.55686275, 0.40392157],
#          [0.82352941, 0.76862745, 0.61568627],
#          [0.75686275, 0.71372549, 0.57254902],
#          ...,
#          [0.61960784, 0.55686275, 0.42352941],
#          [0.63137255, 0.56862745, 0.43529412],
#          [0.6       , 0.5372549 , 0.40392157]],
#
#         [[0.61176471, 0.55686275, 0.41568627],
#          [0.74901961, 0.69411765, 0.54901961],
#          [0.84705882, 0.80392157, 0.6745098 ],
#          ...,
#          [0.57647059, 0.51372549, 0.38039216],
#          [0.57647059, 0.51372549, 0.38039216],
#          [0.57647059, 0.51372549, 0.38039216]],
#
#         [[0.5372549 , 0.48235294, 0.34901961],
#          [0.71764706, 0.65882353, 0.52941176],
#          [0.71764706, 0.6745098 , 0.55686275],
#          ...,
#          [0.61176471, 0.54901961, 0.41568627],
#          [0.60392157, 0.54117647, 0.40392157],
#          [0.58823529, 0.5254902 , 0.39215686]]],
#
#
#        ...,
#
#
#        [[[0.80784314, 0.77254902, 0.79215686],
#          [0.80392157, 0.79215686, 0.77254902],
#          [0.97647059, 0.97647059, 1.        ],
#          ...,
#          [0.90980392, 0.89019608, 0.91764706],
#          [0.67843137, 0.65098039, 0.68235294],
#          [0.92156863, 0.90980392, 0.9372549 ]],
#
#         [[0.76470588, 0.7254902 , 0.72941176],
#          [0.82352941, 0.80392157, 0.81960784],
#          [0.99215686, 0.99607843, 1.        ],
#          ...,
#          [0.96470588, 0.94509804, 0.97254902],
#          [0.98039216, 0.95294118, 0.98431373],
#          [0.93333333, 0.90588235, 0.9372549 ]],
#
#         [[0.63921569, 0.61568627, 0.58431373],
#          [0.79215686, 0.78431373, 0.78823529],
#          [0.58039216, 0.56470588, 0.61960784],
#          ...,
#          [0.83137255, 0.80392157, 0.83529412],
#          [0.94509804, 0.93333333, 0.96078431],
#          [0.98039216, 0.96078431, 0.98823529]],
#
#         ...,
#
#         [[0.82352941, 0.78431373, 0.78823529],
#          [0.81960784, 0.77647059, 0.80392157],
#          [0.87843137, 0.83921569, 0.83529412],
#          ...,
#          [0.94509804, 0.90196078, 0.86666667],
#          [0.83137255, 0.79215686, 0.75294118],
#          [0.83529412, 0.79607843, 0.75686275]],
#
#         [[0.78039216, 0.74901961, 0.74117647],
#          [0.83529412, 0.80784314, 0.8       ],
#          [0.88235294, 0.8627451 , 0.84705882],
#          ...,
#          [0.87058824, 0.83137255, 0.79215686],
#          [0.82352941, 0.78431373, 0.74509804],
#          [0.77647059, 0.73333333, 0.69411765]],
#
#         [[0.87058824, 0.83137255, 0.82745098],
#          [0.88627451, 0.84705882, 0.84313725],
#          [0.8745098 , 0.85490196, 0.84313725],
#          ...,
#          [0.8745098 , 0.84313725, 0.8       ],
#          [0.88235294, 0.84313725, 0.80392157],
#          [0.85490196, 0.81568627, 0.77647059]]],
#
#
#        [[[0.54901961, 0.5254902 , 0.54117647],
#          [0.58039216, 0.55686275, 0.56862745],
#          [0.65098039, 0.63529412, 0.58431373],
#          ...,
#          [0.62352941, 0.55686275, 0.49411765],
#          [0.65098039, 0.57254902, 0.52941176],
#          [0.65098039, 0.52941176, 0.45098039]],
#
#         [[0.58039216, 0.55686275, 0.57254902],
#          [0.68235294, 0.67058824, 0.62745098],
#          [0.58039216, 0.58431373, 0.58039216],
#          ...,
#          [0.65098039, 0.58039216, 0.48627451],
#          [0.7372549 , 0.66666667, 0.6       ],
#          [0.61960784, 0.50980392, 0.43529412]],
#
#         [[0.67843137, 0.65490196, 0.6       ],
#          [0.56078431, 0.55686275, 0.54117647],
#          [0.59215686, 0.58431373, 0.57254902],
#          ...,
#          [0.61568627, 0.50196078, 0.43137255],
#          [0.65490196, 0.49803922, 0.43137255],
#          [0.70196078, 0.67058824, 0.59607843]],
#
#         ...,
#
#         [[0.46666667, 0.40392157, 0.35294118],
#          [0.4627451 , 0.4       , 0.34901961],
#          [0.47843137, 0.4       , 0.36470588],
#          ...,
#          [0.33333333, 0.25490196, 0.16078431],
#          [0.34509804, 0.26666667, 0.17254902],
#          [0.36078431, 0.2627451 , 0.18039216]],
#
#         [[0.45490196, 0.38039216, 0.35294118],
#          [0.46666667, 0.39215686, 0.36470588],
#          [0.44313725, 0.37647059, 0.32941176],
#          ...,
#          [0.35686275, 0.24705882, 0.19215686],
#          [0.36078431, 0.25098039, 0.19607843],
#          [0.35294118, 0.2627451 , 0.2       ]],
#
#         [[0.42745098, 0.36078431, 0.32156863],
#          [0.44313725, 0.35686275, 0.30588235],
#          [0.41176471, 0.36470588, 0.30980392],
#          ...,
#          [0.45490196, 0.40392157, 0.32941176],
#          [0.44705882, 0.39607843, 0.32156863],
#          [0.36078431, 0.2745098 , 0.2       ]]],
#
#
#        [[[0.4627451 , 0.46666667, 0.39607843],
#          [0.46666667, 0.47058824, 0.41568627],
#          [0.47843137, 0.48235294, 0.41176471],
#          ...,
#          [0.5372549 , 0.54509804, 0.49019608],
#          [0.50980392, 0.51764706, 0.4627451 ],
#          [0.47058824, 0.48627451, 0.43137255]],
#
#         [[0.47843137, 0.46666667, 0.4       ],
#          [0.48235294, 0.47058824, 0.40392157],
#          [0.49019608, 0.47843137, 0.41176471],
#          ...,
#          [0.52156863, 0.52941176, 0.4745098 ],
#          [0.51372549, 0.51764706, 0.4627451 ],
#          [0.49019608, 0.49803922, 0.44313725]],
#
#         [[0.48627451, 0.47058824, 0.40392157],
#          [0.49019608, 0.47843137, 0.41176471],
#          [0.49411765, 0.48235294, 0.41568627],
#          ...,
#          [0.52156863, 0.52941176, 0.4745098 ],
#          [0.5254902 , 0.52941176, 0.4745098 ],
#          [0.50588235, 0.51372549, 0.45882353]],
#
#         ...,
#
#         [[0.49019608, 0.43529412, 0.36862745],
#          [0.48235294, 0.43137255, 0.36470588],
#          [0.44705882, 0.39607843, 0.32941176],
#          ...,
#          [0.43921569, 0.38823529, 0.32156863],
#          [0.50196078, 0.45098039, 0.38431373],
#          [0.47058824, 0.41960784, 0.35294118]],
#
#         [[0.43137255, 0.38039216, 0.31764706],
#          [0.54901961, 0.49803922, 0.43529412],
#          [0.51372549, 0.47843137, 0.41176471],
#          ...,
#          [0.4745098 , 0.42352941, 0.36078431],
#          [0.47058824, 0.41960784, 0.35686275],
#          [0.43137255, 0.38039216, 0.31764706]],
#
#         [[0.57254902, 0.5254902 , 0.4627451 ],
#          [0.46666667, 0.41568627, 0.34901961],
#          [0.54509804, 0.49803922, 0.43529412],
#          ...,
#          [0.48235294, 0.43137255, 0.37647059],
#          [0.49411765, 0.44705882, 0.38823529],
#          [0.43529412, 0.38823529, 0.32941176]]]])

# %% [markdown]
# # Save data
# Podemos guardar los arrays de numpy en un archivo `.npz`, de tal manera que luego sea más rápido importarlo

# %%
np.savez(ROOT_PATH + '/data.npz',
        X_train = X_train,
        y_train = y_train,
        X_test = X_test,
        y_test = y_test)

# %%
ROOT_PATH
# Out:
# '/Users/andoni/2026-02-BILBAO-FT-Data-Science/3-Machine_Learning/3-Deep_Learning/2-Redes_Convolucionales/dogs_cats/'

# %% [markdown]
# Para cargar

# %%
data = np.load(ROOT_PATH + '/data.npz')
X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']

# %% [markdown]
# # Build Model
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %% [markdown]
# * **Conv Layer**: extraerá diferentes features de las imagenes
# * **Pooling Layer**: Reduce las dimensiones de las imágenes tras una capa convolucional
# * **Fully Connected Layer**: Tras las capas convolucionales, aplanamos las features y las introducimos como entrada de una red neuronal normal.
# * **Output Layer**: Las predicciones de la red
#
# Para el loss y la metrica, se puede usar un binary_crossentropy, al ser un target binario.

# %%
IMAGE_SIZE
# Out:
# (32, 32, 3)

# %%
from tensorflow import keras

layers = [
    keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=IMAGE_SIZE),
    keras.layers.MaxPooling2D(pool_size=(2,2)),
    
    keras.layers.Conv2D(128, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2)),
    
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
]

model = keras.Sequential(layers)

model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 673921 (2.57 MB)
# Trainable params: 673921 (2.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Callbacks
# #### Early Stopping

# %%
from keras.callbacks import EarlyStopping
earlystop = EarlyStopping(patience=10)

# %%
from keras.callbacks import ModelCheckpoint
mcheckpoint = ModelCheckpoint("callback_model.keras")

# %% [markdown]
# # Fit the model

# %%
history = model.fit(X_train,
         y_train,
         epochs = EPOCHS,
         batch_size = BATCH_SIZE,
         callbacks = [earlystop, mcheckpoint],
         validation_split = 0.2)
# Out:
# Epoch 1/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.6661 - accuracy: 0.6135 - val_loss: 0.6077 - val_accuracy: 0.6626
# Epoch 2/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.6124 - accuracy: 0.6633 - val_loss: 0.5825 - val_accuracy: 0.6884
# Epoch 3/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.5465 - accuracy: 0.7219 - val_loss: 0.5352 - val_accuracy: 0.7310
# Epoch 4/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.5016 - accuracy: 0.7549 - val_loss: 0.5400 - val_accuracy: 0.7386
# Epoch 5/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.4635 - accuracy: 0.7793 - val_loss: 0.5103 - val_accuracy: 0.7584
# Epoch 6/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.4194 - accuracy: 0.8049 - val_loss: 0.5226 - val_accuracy: 0.7416
# Epoch 7/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.3704 - accuracy: 0.8344 - val_loss: 0.6529 - val_accuracy: 0.7264
# Epoch 8/30
# 165/165 [==============================] - 2s 12ms/step - loss: 0.3205 - accuracy: 0.8610 - val_loss: 0.5984 - val_accuracy: 0.7462
# Epoch 9/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.2617 - accuracy: 0.8876 - val_loss: 0.6610 - val_accuracy: 0.7606
# Epoch 10/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.2035 - accuracy: 0.9177 - val_loss: 0.7058 - val_accuracy: 0.7576
# Epoch 11/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.1471 - accuracy: 0.9414 - val_loss: 0.7841 - val_accuracy: 0.7416
# Epoch 12/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.1242 - accuracy: 0.9548 - val_loss: 0.9093 - val_accuracy: 0.7249
# Epoch 13/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.0828 - accuracy: 0.9702 - val_loss: 1.0564 - val_accuracy: 0.7386
# Epoch 14/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.0499 - accuracy: 0.9831 - val_loss: 1.2948 - val_accuracy: 0.7135
# Epoch 15/30
# 165/165 [==============================] - 2s 13ms/step - loss: 0.1048 - accuracy: 0.9599 - val_loss: 1.1431 - val_accuracy: 0.7432

# %%
results = model.evaluate(X_test, y_test)
print("test loss, test acc:", results)
# Out:
# 108/108 [==============================] - 0s 4ms/step - loss: 1.3878 - accuracy: 0.7052
# test loss, test acc: [1.3878365755081177, 0.7051504850387573]

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(history.history).head(10)
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.666051  0.613498  0.607679      0.662614
# 1  0.612377  0.663308  0.582481      0.688450
# 2  0.546542  0.721863  0.535246      0.731003
# 3  0.501604  0.754943  0.540050      0.738602
# 4  0.463531  0.779278  0.510287      0.758359
# 5  0.419416  0.804943  0.522583      0.741641
# 6  0.370450  0.834411  0.652941      0.726444
# 7  0.320542  0.861027  0.598395      0.746201
# 8  0.261663  0.887643  0.661041      0.760638
# 9  0.203530  0.917681  0.705784      0.757599

# %% [markdown]
# # Evaluate
# Probemos los datos en el conjunto de test.

# %%
results = model.evaluate(X_test, y_test)
results
# Out:
# 108/108 [==============================] - 0s 4ms/step - loss: 1.3878 - accuracy: 0.7052
# [1.3878365755081177, 0.7051504850387573]

# %%
model.predict(X_test).round(0)
# Out:
# 108/108 [==============================] - 0s 4ms/step
# array([[0.],
#        [1.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, model.predict(X_test).round(0))
# Out:
# 108/108 [==============================] - 0s 4ms/step
# array([[1427,  221],
#        [ 798, 1010]])

# %%
plt.imshow(X_test[-3]);

# %%
X_test[-4:-3]
# Out:
# array([[[[0.41176471, 0.42352941, 0.45882353],
#          [0.42745098, 0.43921569, 0.4745098 ],
#          [0.45882353, 0.47058824, 0.50588235],
#          ...,
#          [0.1254902 , 0.14509804, 0.12941176],
#          [0.32941176, 0.34509804, 0.36862745],
#          [0.41568627, 0.44313725, 0.48235294]],
#
#         [[0.40784314, 0.41960784, 0.45490196],
#          [0.45882353, 0.47058824, 0.50588235],
#          [0.45098039, 0.4627451 , 0.50196078],
#          ...,
#          [0.15294118, 0.17254902, 0.15686275],
#          [0.43529412, 0.44705882, 0.4745098 ],
#          [0.4627451 , 0.48627451, 0.54901961]],
#
#         [[0.44705882, 0.45490196, 0.49411765],
#          [0.47843137, 0.49019608, 0.5254902 ],
#          [0.49803922, 0.50980392, 0.54509804],
#          ...,
#          [0.21568627, 0.23529412, 0.22352941],
#          [0.4627451 , 0.47843137, 0.50980392],
#          [0.50196078, 0.52941176, 0.56862745]],
#
#         ...,
#
#         [[0.61960784, 0.61960784, 0.61960784],
#          [0.70588235, 0.69019608, 0.67843137],
#          [0.60784314, 0.58823529, 0.57254902],
#          ...,
#          [0.47843137, 0.4745098 , 0.46666667],
#          [0.81568627, 0.80784314, 0.81960784],
#          [0.81568627, 0.79215686, 0.8       ]],
#
#         [[0.82745098, 0.82745098, 0.82745098],
#          [0.82352941, 0.80784314, 0.79607843],
#          [0.71764706, 0.69803922, 0.68235294],
#          ...,
#          [0.57254902, 0.56862745, 0.56078431],
#          [0.78431373, 0.77647059, 0.78823529],
#          [0.72941176, 0.70588235, 0.71372549]],
#
#         [[0.82745098, 0.81960784, 0.83921569],
#          [0.42745098, 0.40392157, 0.41176471],
#          [0.39607843, 0.36470588, 0.36862745],
#          ...,
#          [0.5254902 , 0.51764706, 0.52156863],
#          [0.48627451, 0.47843137, 0.48235294],
#          [0.84313725, 0.83921569, 0.83137255]]]])

# %%
predictions = model.predict(X_test[-4:-3])
predictions
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([[0.00011037]], dtype=float32)

# %% [markdown]
# # Image data generator

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

print("Categorias:", df['category'].unique())
df.head()
# Out:
# Categorias: ['cat' 'dog']
#         filename category
# 0   cat.2718.jpg      cat
# 1   cat.3406.jpg      cat
# 2   cat.1211.jpg      cat
# 3  dog.11102.jpg      dog
# 4  dog.11664.jpg      dog

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

example_df = df.sample(n=1).reset_index(drop=True)
example_df

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    shear_range = 0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

example_generator = train_datagen.flow_from_dataframe(
    example_df,
    TRAIN_PATH,
    x_col = 'filename',
    y_col = 'category',
    target_size = (128, 128)
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
example_df
# Out:
#       filename category
# 0  cat.770.jpg      cat

# %%
plt.figure(figsize=(12, 12))

for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Training Generator

# %%
train_df, validate_df = train_test_split(df,
                                         test_size=0.20,
                                         random_state=42)

train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

print("Shape train", total_train)
print("Shape validation", total_validate)
validate_df.head()
# Out:
# Shape train 5260
# Shape validation 1316
#         filename category
# 0    cat.818.jpg      cat
# 1   cat.3133.jpg      cat
# 2   cat.3204.jpg      cat
# 3  dog.10405.jpg      dog
# 4   cat.2145.jpg      cat

# %%
train_df.head()
# Out:
#         filename category
# 0   cat.1088.jpg      cat
# 1   cat.1169.jpg      cat
# 2     cat.91.jpg      cat
# 3  dog.10489.jpg      dog
# 4    cat.485.jpg      cat

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    shear_range = 0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    TRAIN_PATH, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    class_mode='binary',
    batch_size=BATCH_SIZE
)
# Out:
# Found 5260 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    TRAIN_PATH, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    class_mode='binary',
    batch_size=BATCH_SIZE
)
# Out:
# Found 1316 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Fit Model

# %%
model = keras.Sequential(layers)

model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
history = model.fit(
    train_generator,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data = validation_generator
)
# Out:
# Epoch 1/30
# 165/165 [==============================] - 6s 33ms/step - loss: 0.5726 - accuracy: 0.7352 - val_loss: 0.3500 - val_accuracy: 0.8518
# Epoch 2/30
# 165/165 [==============================] - 5s 30ms/step - loss: 0.5156 - accuracy: 0.7433 - val_loss: 0.3262 - val_accuracy: 0.8944
# Epoch 3/30
# 165/165 [==============================] - 5s 31ms/step - loss: 0.4919 - accuracy: 0.7713 - val_loss: 0.3819 - val_accuracy: 0.8450
# Epoch 4/30
# 165/165 [==============================] - 5s 33ms/step - loss: 0.4848 - accuracy: 0.7663 - val_loss: 0.3425 - val_accuracy: 0.8579
# Epoch 5/30
# 165/165 [==============================] - 6s 35ms/step - loss: 0.4855 - accuracy: 0.7641 - val_loss: 0.3337 - val_accuracy: 0.8640
# Epoch 6/30
# 165/165 [==============================] - 5s 33ms/step - loss: 0.4592 - accuracy: 0.7819 - val_loss: 0.4196 - val_accuracy: 0.8070
# Epoch 7/30
# 165/165 [==============================] - 5s 33ms/step - loss: 0.4581 - accuracy: 0.7846 - val_loss: 0.3372 - val_accuracy: 0.8488
# Epoch 8/30
# 165/165 [==============================] - 5s 32ms/step - loss: 0.4510 - accuracy: 0.7890 - val_loss: 0.3110 - val_accuracy: 0.8685
# Epoch 9/30
# 165/165 [==============================] - 6s 35ms/step - loss: 0.4573 - accuracy: 0.7842 - val_loss: 0.3770 - val_accuracy: 0.8305
# Epoch 10/30
# 165/165 [==============================] - 5s 32ms/step - loss: 0.4436 - accuracy: 0.7894 - val_loss: 0.4325 - val_accuracy: 0.7796
# Epoch 11/30
# 165/165 [==============================] - 5s 32ms/step - loss: 0.4568 - accuracy: 0.7901 - val_loss: 0.3325 - val_accuracy: 0.8480
# Epoch 12/30
# 165/165 [==============================] - 6s 38ms/step - loss: 0.4386 - accuracy: 0.7903 - val_loss: 0.3803 - val_accuracy: 0.8313
# Epoch 13/30
# 165/165 [==============================] - 7s 40ms/step - loss: 0.4418 - accuracy: 0.7913 - val_loss: 0.3443 - val_accuracy: 0.8488
# Epoch 14/30
# 165/165 [==============================] - 7s 42ms/step - loss: 0.4199 - accuracy: 0.8057 - val_loss: 0.3543 - val_accuracy: 0.8427
# Epoch 15/30
# 165/165 [==============================] - 8s 48ms/step - loss: 0.4153 - accuracy: 0.8103 - val_loss: 0.5483 - val_accuracy: 0.7128
# Epoch 16/30
# 165/165 [==============================] - 10s 63ms/step - loss: 0.4266 - accuracy: 0.7987 - val_loss: 0.3749 - val_accuracy: 0.8435
# Epoch 17/30
# 165/165 [==============================] - 11s 67ms/step - loss: 0.4103 - accuracy: 0.8089 - val_loss: 0.4578 - val_accuracy: 0.7865
# Epoch 18/30
# 165/165 [==============================] - 8s 50ms/step - loss: 0.4132 - accuracy: 0.8042 - val_loss: 0.3485 - val_accuracy: 0.8571
# Epoch 19/30
# 165/165 [==============================] - 10s 63ms/step - loss: 0.4178 - accuracy: 0.8034 - val_loss: 0.3842 - val_accuracy: 0.8336
# Epoch 20/30
# 165/165 [==============================] - 9s 53ms/step - loss: 0.4010 - accuracy: 0.8196 - val_loss: 0.3470 - val_accuracy: 0.8473
# Epoch 21/30
# 165/165 [==============================] - 6s 39ms/step - loss: 0.3951 - accuracy: 0.8156 - val_loss: 0.3509 - val_accuracy: 0.8488
# Epoch 22/30
# 165/165 [==============================] - 6s 38ms/step - loss: 0.3954 - accuracy: 0.8133 - val_loss: 0.3809 - val_accuracy: 0.8313
# Epoch 23/30
# 165/165 [==============================] - 6s 37ms/step - loss: 0.3901 - accuracy: 0.8190 - val_loss: 0.3556 - val_accuracy: 0.8488
# Epoch 24/30
# 165/165 [==============================] - 6s 35ms/step - loss: 0.3834 - accuracy: 0.8224 - val_loss: 0.4378 - val_accuracy: 0.8070
# Epoch 25/30
# 165/165 [==============================] - 6s 37ms/step - loss: 0.3814 - accuracy: 0.8276 - val_loss: 0.5591 - val_accuracy: 0.7546
# Epoch 26/30
# 165/165 [==============================] - 6s 38ms/step - loss: 0.3722 - accuracy: 0.8344 - val_loss: 0.5524 - val_accuracy: 0.7371
# Epoch 27/30
# 165/165 [==============================] - 6s 34ms/step - loss: 0.3709 - accuracy: 0.8344 - val_loss: 0.4646 - val_accuracy: 0.7971
# Epoch 28/30
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3778 - accuracy: 0.8293 - val_loss: 0.3921 - val_accuracy: 0.8283
# Epoch 29/30
# 165/165 [==============================] - 5s 29ms/step - loss: 0.3666 - accuracy: 0.8276 - val_loss: 0.4889 - val_accuracy: 0.7834
# Epoch 30/30
# 165/165 [==============================] - 5s 30ms/step - loss: 0.3508 - accuracy: 0.8407 - val_loss: 0.3926 - val_accuracy: 0.8260

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
##### CODE #####

# Listar todos los archivos de la carpeta de train (TEST_PATH)
filenames = os.listdir(TEST_PATH)

# Lista vacia
categories = []

# Iterar
for filename in filenames:
    # Saco el nombre
    category = filename.split('.')[0]
    
    # If else
    # Guardo en lista
    if category == 'dog':
        categories.append('dog')
    else:
        categories.append('cat')
    
    
test_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
test_df
# Out:
#            filename category
# 0     cat.12020.jpg      cat
# 1      dog.9469.jpg      dog
# 2     cat.11529.jpg      cat
# 3      dog.8777.jpg      dog
# 4      dog.8763.jpg      dog
# ...             ...      ...
# 3451   dog.9470.jpg      dog
# 3452  cat.11530.jpg      cat
# 3453  cat.12039.jpg      cat
# 3454  cat.11256.jpg      cat
# 3455   dog.9316.jpg      dog
#
# [3456 rows x 2 columns]

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    test_df, 
    TEST_PATH, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    class_mode='binary',
    batch_size=BATCH_SIZE
)
# Out:
# Found 3456 validated image filenames belonging to 2 classes.

# %%
len(test_generator)
# Out:
# 108

# %%
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# 108/108 [==============================] - 2s 20ms/step - loss: 0.4404 - accuracy: 0.8058
# test loss, test acc: [0.4403996765613556, 0.8058449029922485]

# %%
results = model.evaluate(X_test, y_test)
print("test loss, test acc:", results)
# Out:
# 108/108 [==============================] - 1s 4ms/step - loss: 0.4349 - accuracy: 0.8079
# test loss, test acc: [0.43493667244911194, 0.8078703880310059]

# %% [markdown]
# # Virtualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, EPOCHS, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='g', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='orange',label="Validation accuracy")
ax2.set_xticks(np.arange(1, EPOCHS, 1))

plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()
