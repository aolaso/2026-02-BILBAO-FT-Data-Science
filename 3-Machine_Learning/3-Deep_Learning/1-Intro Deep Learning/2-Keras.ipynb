# %% [markdown]
# # Keras
# Librería para programar redes neuronales de una manera más sencilla que con TensorFlow. Keras se encuentra en una capa de abstracción por encima de TensorFlow.
#
# [Documentación](https://keras.io/guides/)

# %%
# %pip install tensorflow keras
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.4 kB)
# Collecting keras
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.80.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from tensorflow) (2.3.5)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (8.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Collecting rich (from keras)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras)
#   Downloading optree-0.19.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ds/lib/python3.11/site-packages (from rich->keras) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.21.0-cp311-cp311-macosx_12_0_arm64.whl (223.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.4/223.4 MB 10.9 MB/s  0:00:20m0:00:0100:01
# Downloading grpcio-1.80.0-cp311-cp311-macosx_11_0_universal2.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 11.7 MB/s  0:00:01 eta 0:00:01
# Downloading h5py-3.14.0-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 15.3 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp311-cp311-macosx_10_9_universal2.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 11.2 MB/s  0:00:00
# Downloading keras-3.14.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.4 MB/s  0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 14.6 MB/s  0:00:01 eta 0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp311-cp311-macosx_11_0_arm64.whl (378 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, termcolor, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, absl-py, markdown-it-py, astunparse, rich, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [tensorflow]9 [tensorflow]a]
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.14.0 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 wrapt-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
## Si tienes una gráfica Nvidia
# %pip install tensorflow[and-cuda] keras

# %% [markdown]
# Empezamos importando librerías

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import numpy as np

# %% [markdown]
# Cargamos los datos de mnist. No vamos a tratar imagenes con redes convolucionales (perdemos la estructura espacial 2D). Todos los pixeles se convertirán en un vector de 28x28 features independientes, que serán las entradas del modelo.

# %%
# Cogemos las imágenes de los dígitos asi como el conjunto de train y test
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %% [markdown]
# Vemos dimensiones del dataset

# %%
'''
60.000 imagenes de 28x28 pixeles
'''
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %%
len(np.unique(y_test))

# %%
X_train[0]

# %%
2**8 # niveles de gris

# %% [markdown]
# 60.000 imágenes de 28x28 pixeles. Vamos a representar una de ellas

# %%
import matplotlib.pyplot as plt

plt.imshow(X_train[0], cmap=plt.cm.get_cmap('Greys'));

# %% [markdown]
# Cada imagen se compone de 28x28 pixeles, y cada pixel representa una escala de grises que va del 0 al 255. Siendo 0 el blanco y 255 negro.
#
# ¿Se te ocurre alguna manera de normalizar los datos?

# %%
np.max(X_train)

# %%
0/255

# %%
128/255

# %%
255/255

# %%
X_train = X_train.astype("float32")/255
X_test = X_test.astype("float32")/255

# %%
np.mean(X_train)

# %%
'''
Comprobamos la normalización
'''
X_train[0]

# %%
y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# %% [markdown]
# Guardamos datos para validación. Estos datos se usarán durante el entrenamiento. Otra opción es decirle a keras en la etapa de entrenamiento que reserve un X % de los datos para validar.

# %%
X_val = X_train[-10000:]
y_val = y_train[-10000:]

X_train = X_train[:-10000]
y_train = y_train[:-10000]

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)

# %% [markdown]
# Montamos la arquitectura de la red neuronal. Se va a componer de:
# * **Sequential**: API para iniciar la red neuronal. No cuenta como capa.
# * **Flatten**: capa de entrada. Necesita un vector unidimensional. Como tenemos imágenes, esta capa aplana las imagenes (2D) en 1D.
# * **Dense**: es una hidden layer. Se compondrá de `n` neuronas y de una función de activación que se aplicará a todas las neuronas de la capa.
#
# Recuerda que es un problema de clasificación multiclase (10 clases) y que por tanto la última capa se compondrá de tantas neuronas como clases tengas.
#
# En cuanto a las funciones de activación es recomendable usar relu en las hidden layer, que tarda menos en entrenar, mientras que la ultima (output) suele ser una softmax.

# %%
28*28

# %%
X_train.shape

# %%
model = keras.models.Sequential()

# Capa entrada
model.add(keras.layers.Flatten(input_shape=(28, 28)))

# Hidden layer
model.add(keras.layers.Dense(units = 300,
                            activation='relu'))

# Hidden layer
model.add(keras.layers.Dense(units = 100,
                            activation='relu'))

# Capa salida
model.add(keras.layers.Dense(units = 10,
                            activation='softmax'))

# %%
# Otra manera de declarar la red neuronal
capas = [
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(units = 300, activation='relu'),
    keras.layers.Dense(units = 100, activation='relu'),
    keras.layers.Dense(units = 10, activation='softmax')
]

model = keras.models.Sequential(capas)

# %% [markdown]
# Podemos ver las capas, y acceder a sus elementos

# %%
print(model.layers[0])

# %% [markdown]
# Podemos ver los pesos de las capas sin entrenar, porque los inicializa aleatoriamente. Los bias los inicializa a 0.

# %%
hidden1 = model.layers[1]
weights, biases = hidden1.get_weights()

# %%
weights

# %%
len(weights)

# %%
len(weights[0])

# %%
28*28

# %%
300*784

# %%
weights.size

# %%
len(biases)

# %% [markdown]
# Establecemos la configuración de ejecución... el compile.

# %%
model.compile(
    optimizer = keras.optimizers.SGD(),
    loss = keras.losses.SparseCategoricalCrossentropy(),
    metrics = [keras.metrics.SparseCategoricalAccuracy()]
)

# %%
# Equivalente
model.compile(
    optimizer = "sgd",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
# Summary
model.summary()

# %%
784 * 300 + 300

# %%
# 1º neurona de la 1º hidden layer
# y = a + w1*x1 + w2*x2 + .... wn*xn
# a es el intercepto llamado bias
# wn es cada uno de los pesos que va a ir actualizando con el backpropagation
# n es 784
# En la 1º hidden layer tenemos 784 pesos por cada neurona, al tener 300, tenemos un total de:
print(784*300 + 300)

# %%
300 * 784 + 300

# %%
300 * 100 + 100

# %%
100 * 10 + 10

# %% [markdown]
# Entrenamos el modelo. Usamos los datos de entrenamiento. El batch_size es la cantidad de muestras que utiliza el SGD, y las epochs son las iteraciones que realiza en el entrenamiento.

# %%
X_train.shape

# %%
50000/128

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size = 128,
    epochs = 50,
    validation_data = (X_val, y_val) # validation_split = 0.1
)

# %% [markdown]
# Podemos reentrenar el modelo. No empieza de nuevo, sino que retoma el entrenamiento anterior.

# %%
model.fit(
    X_train,
    y_train,
    batch_size = 64,
    epochs = 10,
    validation_data = (X_val, y_val) # validation_split = 0.1
)

# %% [markdown]
# Veamos el histórico del entrenamiento, para poder representarlo posteriormente.

# %%
# print(history.params)
# print(history.epoch)
print(history.history)

# %%
history.history

# %%
history.history.keys()

# %%
pd.DataFrame(history.history)

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %% [markdown]
# Si el modelo no ha ido bien, prueba a cambiar el learning rate, cambia de optimizador y después prueba a cambiar capas, neuronas y funciones de activación.
#
# Ya tenemos el modelo entrenado. Probémoslo con test

# %%
results = model.evaluate(X_test, y_test)
results

# %%
# Cogemos el primero
plt.imshow(X_test[0].reshape(28,28), cmap=plt.cm.get_cmap('Greys'));

# %%
X_test[:1]

# %%
predictions = model.predict(X_test[:1])
print(predictions.shape)
predictions

# %%
predictions.argmax()

# %%
model.predict(X_test).argmax(axis=1)

# %%
plt.imshow(X_test[1].reshape(28,28), cmap=plt.cm.get_cmap('Greys'));

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, model.predict(X_test).argmax(axis=1))

# %% [markdown]
# ### Problema de regresión
# Veamos un ejemplo de cómo aplicar una red neuronal de TensorFlow a un problema de regresión.

# %%
# Cargamos datos
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns = housing.feature_names)
df['target'] = housing['target']
df.head()

# %% [markdown]
# Divimos en train, test y validation

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data,
                                                              housing.target)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_full,
                                                      y_train_full)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
X_train.shape

# %% [markdown]
# Montamos el modelo. Simplemente se compondrá de una hidden layer, a la que le configuramos una capa previa de entrada de 8 neuronas (las features).
#
# Se trata de un modelo de regresión, por lo que la capa de salida es una única neurona.

# %%
11610/32

# %%
X_train.shape

# %%
X_train.shape[1:]

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation = 'relu',
                      input_shape = X_train.shape[1:]),
    keras.layers.Dense(1)
])

model.compile(loss = "mean_squared_error",
             optimizer = "sgd")

history = model.fit(X_train,
                   y_train,
                   epochs = 20,
                   validation_data = (X_valid, y_valid))

# %%
8*30 + 30

# %%
model.summary()

# %%
8*30+30

# %%
mse_test = model.evaluate(X_test, y_test)
print(mse_test)

# %%
y_pred = model.predict(X_test[:5])
y_pred

# %% [markdown]
# ### Guardar modelo
# Para guardar el modelo, en el formato de Keras (HDF5).

# %%
model.save("my_keras_model.keras")

# %%
# Lo volvemos a cargar
model = keras.models.load_model("my_keras_model.keras")

# %% [markdown]
# ### Callbacks
# Son funciones predefinidas de Keras a aplicar durante el entrenamiento
# Por ejemplo, `ModelCheckpoint` sirve para que el modelo se vaya guardando tras cada epoch. Así no perdemos el progreso en caso de que decidamos interrumpir el entrenamiento. El callback recibe como argumento el nombre del objeto donde queremos que se guarde el modelo entrenado.

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("callback_model.keras")
history = model.fit(X_train,
                   y_train,
                   epochs=30,
                   callbacks = [checkpoint_cb])

# %% [markdown]
# ### Early Stopping
# Interrumpe el entrenamiento cuando no ve progreso en el set de validación. Para ello tiene en cuenta un numero de epochs llamado `patience`. Se puede combinar con el callback

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10)
history = model.fit(X_train,
                   y_train,
                   epochs=50,
                   validation_data = (X_valid, y_valid),
                   callbacks = [early_stopping_cb, checkpoint_cb])

# %%
history_df = pd.DataFrame(history.history).plot()
